# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
afbeelding = cv.imread('kodak dataset/kodim23.png')

# %%
# convert to RGB
afbeelding = cv.cvtColor(afbeelding, cv.COLOR_BGR2RGB)

# %%
plt.imshow(afbeelding)
plt.show()

# %%
# Dit is de blur kernel
kernel = np.ones((3,3),np.float32)/9
kernel
# Out:
# array([[0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111]], dtype=float32)

# %%
# Pas de convolutie toe op de afbeelding.
afbeelding = cv.filter2D(afbeelding,-1,kernel)

# %%
# De afbeelding is nu een beetje vervaagd. 
# Bij een grotere kernel wordt de vervaging groter
plt.imshow(afbeelding)
plt.show()
