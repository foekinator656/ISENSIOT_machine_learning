# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
afbeelding = cv.imread('kodak dataset/kodim23.png')
# convert to RGB
afbeelding = cv.cvtColor(afbeelding, cv.COLOR_BGR2RGB)

# %%
plt.imshow(afbeelding)
plt.show()

# %%
afbeelding.shape
# Out:
# (512, 768, 3)

# %%
# Hier selecteer ik een gebied uit de originele image. 
roi = afbeelding[200:350,100:250,:]

# %%
# We plotten het geselecteerde gebied
plt.imshow(roi)
plt.show()
