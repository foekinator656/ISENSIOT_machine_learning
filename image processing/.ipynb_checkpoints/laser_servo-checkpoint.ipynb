# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
afbeelding = cv.imread('kodak dataset/test.jpg')
# convert to RGB
laser = cv.cvtColor(afbeelding, cv.COLOR_BGR2RGB)

# %%
rood = laser[:,:,0]

# %%
plt.imshow(rood)
plt.show()

# %%
f_g = rood.flatten()

# %%
plt.hist(f_g,bins=50)
plt.show()

# %%
# De drempelwaarde
newimage = rood>253

# %%
newimage
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.imshow(newimage,cmap='gray')
plt.show()

# %%
np.sum(newimage==True)
# Out:
# 23
