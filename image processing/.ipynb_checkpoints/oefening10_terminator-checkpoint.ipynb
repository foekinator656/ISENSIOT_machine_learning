# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
im1 = plt.imread('kodak dataset/kodim23.png')

# %%
plt.imshow(im1)
plt.show()

# %%
im1.shape
# Out:
# (512, 768, 3)

# %%
mask = np.zeros([512, 768])

# %%
mask[100:400,300:500]=1

# %%
plt.imshow(mask,cmap='gray')
plt.show()

# %%
mask = mask!=1

# %%
im1[:,:,0] = im1[:,:,0]*mask
im1[:,:,1] = im1[:,:,1]*mask
im1[:,:,2] = im1[:,:,2]*mask

# %%
plt.imshow(im1)
plt.show()
