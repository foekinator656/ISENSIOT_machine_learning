# %%
import matplotlib.image as mpimg
import matplotlib.colors as abc
import matplotlib.pyplot as plt
import numpy as np
import cv2
import colorsys

# %%
im1 = plt.imread('kodak dataset/tafel_met_bal.jpg')
bg1 = plt.imread('kodak dataset/tafel_zonder_bal.jpg')

# %%
kernel = np.ones((5,5),np.float32)/25
im1 = cv2.filter2D(im1,-1,kernel)
bg1 = cv2.filter2D(bg1,-1,kernel)

#im1 = cv2.GaussianBlur(im1,(5,5),0)
#bg1 = cv2.GaussianBlur(bg1,(3,3),0)

# %%
plt.imshow(im1)
plt.show()
plt.imshow(bg1)
plt.show()

# %%
np.min(im1)
# Out:
# 0

# %%
plt.imshow(im1[:,:,0],cmap='gray')

# %%
plt.hist(im1[:,:,1].flatten(),bins=50)
plt.show()
plt.hist(bg1[:,:,1].flatten(),bins=50)
plt.show()

# %%
plt.scatter(im1[:,:,2],bg1[:,:,2])
plt.show()

# %%
temp = 0.5*np.sqrt(2)

channel = 1
x_accent = im1[:,:,channel]*temp-bg1[:,:,channel]*temp
y_accent = im1[:,:,channel]*temp+bg1[:,:,channel]*temp

# %%
type(im1[:,:,1])
# Out:
# numpy.ndarray

# %%
plt.hist((x_accent.flatten()),bins=50)
plt.show()

# %%
plt.imshow((x_accent)>20)
plt.show()

# %%
shadow = x_accent>-10

# %%
red   = (bg1[:,:,0].astype('int16')/255-im1[:,:,0].astype('int16')/255)**2
green = (bg1[:,:,1].astype('int16')/255-im1[:,:,1].astype('int16')/255)**2
blue  = (bg1[:,:,2].astype('int16')/255-im1[:,:,2].astype('int16')/255)**2
diff = np.sqrt(red+green)

# %%
red   = np.abs(bg1[:,:,0].astype('int16')/255-im1[:,:,0].astype('int16')/255)
green = np.abs(bg1[:,:,1].astype('int16')/255-im1[:,:,1].astype('int16')/255)
blue  = np.abs(bg1[:,:,2].astype('int16')/255-im1[:,:,2].astype('int16')/255)
manhattan = (red+green)

# %%
red   = (bg1[:,:,0].astype('int16')/255)**2
green = (bg1[:,:,1].astype('int16')/255)**2
blue  = (bg1[:,:,2].astype('int16')/255)**2
lenbg1 = np.sqrt(red+green)

# %%
red   = (im1[:,:,0].astype('int16')/255)**2
green = (im1[:,:,1].astype('int16')/255)**2
blue  = (im1[:,:,2].astype('int16')/255)**2
lenim1 = np.sqrt(red+green)

# %%
dot0 = bg1[:,:,0].astype('int16')/255*im1[:,:,0].astype('int16')/255
dot1 = bg1[:,:,1].astype('int16')/255*im1[:,:,1].astype('int16')/255
dot2 = bg1[:,:,2].astype('int16')/255*im1[:,:,2].astype('int16')/255

# %%
np.min(lenim1)

# %%
angle = (dot0+dot1)/((lenbg1)*(lenim1))

# %%
plt.scatter(manhattan, angle)

# %%
th1 = diff>0.2

# %%
plt.hist(diff.flatten(),bins=100)
plt.show()

# %%
dummy = np.copy(im1)
dummy[:,:,0] = dummy[:,:,0]*th1
dummy[:,:,1] = dummy[:,:,1]*th1
dummy[:,:,2] = dummy[:,:,2]*th1

# %%
plt.imshow(dummy)

# %%
lenbg1.shape

# %%
smooth = np.ones((3,3),np.float32)/9

# %%
dst = cv2.filter2D(angle,-1,smooth)
#dst = cv2.GaussianBlur(angle,(10,10),0)
#dst = cv2.medianBlur(angle,5)

# %%
plt.hist(angle.flatten(),bins=100)
plt.show()
plt.hist(dst.flatten(),bins=100)
plt.show()

# %%
th = angle<0.999
th2 = dst<0.999

# %%
dummy2 = np.copy(im1)
dummy2[:,:,0] = dummy2[:,:,0]*th
dummy2[:,:,1] = dummy2[:,:,1]*th
dummy2[:,:,2] = dummy2[:,:,2]*th

dummy1 = np.copy(im1)
dummy1[:,:,0] = dummy1[:,:,0]*th2
dummy1[:,:,1] = dummy1[:,:,1]*th2
dummy1[:,:,2] = dummy1[:,:,2]*th2

# %%
dummy1[:,:,0] = dummy1[:,:,0]*shadow
dummy1[:,:,1] = dummy1[:,:,1]*shadow
dummy1[:,:,2] = dummy1[:,:,2]*shadow

# %%
plt.imshow(dummy2)
plt.show()
plt.imshow(dummy1)
plt.show()

# %%
# https://www.youtube.com/watch?v=uCDtDonjNxk

# %%
labels = kmeans.predict(indices)

# %%
indices = np.argwhere(th)

# %%
indices.shape

# %%
print(indices)

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(indices)

# %%
indices[10763387][1]

# %%
mask = np.zeros([3000,4000])
for k in range(1236612):
    if labels[k]==2:
        index = indices[k]
        mask[index[0],index[1]] = 255

# %%
plt.imshow(mask)

# %%
template = mpimg.imread('koelkast/template.jpg')

# %%
plt.imshow(template)
plt.show()

# %%
template.shape

# %%
plt.hist(template[:,:,2].flatten(),bins=8)

# %%
histogram, bin_edges = np.histogram(template[:,:,2], bins=[0,32,64,96,128,160,192,224,255])

# %%
histogram

# %%
bin_edges

# %%
plt.scatter(angle.flatten(),diff.flatten())
